# %%
import pandas as pd
import matplotlib as plt
import sklearn
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import numpy as np
import scipy.stats
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

covariates = pd.read_csv("eqtl_covariates_num_encoded_20201001.tsv", sep="\t")

covariates.rename(columns={"id": "IID"}, inplace=True)
covariates = covariates.loc[covariates["anypards"] == 1.0]

covariates.head()
# Out:
#       IID  anypards  male  race  ethnic   prismrom  death90  ventfreeday
# 0  01-002       1.0     0     7       2  44.296434      0.0    15.696528
# 1  01-003       1.0     0     7       2   0.719391      0.0    24.776389
# 2  01-004       1.0     1     7       3  86.372035      0.0    25.061111
# 3  01-005       1.0     0     7       2  22.785551      0.0    27.318056
# 4  01-006       1.0     1     7       3   0.950055      0.0    25.104167

# %%
import seaborn as sns
AC011462 = pd.read_csv("make_score/AC011462.1.plink.profile", sep=r"\s*")
AC011462 = pd.merge(AC011462, covariates, on="IID" )
axes = AC011462.boxplot(column=['SCORE'], by='death90')

fig = axes.get_figure()
fig.suptitle('')

x = AC011462[["SCORE", "male", "race", "ethnic", "prismrom", "ventfreeday", "PHENO"]]
y = AC011462[["death90"]]
print(scipy.stats.ttest_ind(x,y))
print(" ")
print("-------------LOGISTIC REGRESSION BELOW-----------------")
print(" ")
log_model_sm = sm.Logit(y, x)
sm_result = log_model_sm.fit(maxiter=500)
print(" ")
print("Stats models logistic regression pvalues\n",sm_result.pvalues)

print(" ")
print("stats models pckg: log model ",sm_result.summary())

AC011462.head()
# Out:
# Ttest_indResult(statistic=array([ 1.83115243,  8.95841866, 34.54411864, 55.64835405, 12.16177579,
#        22.68567751, -4.63507663]), pvalue=array([6.77447310e-002, 9.02395961e-018, 3.79046362e-128, 8.03784693e-203,
#        1.37462701e-029, 2.52563270e-076, 4.69190550e-006]))
#
# -------------LOGISTIC REGRESSION BELOW-----------------
#
# ...
#          Current function value: 0.184824
#          Iterations: 500
#
# Stats models logistic regression pvalues
#  SCORE          9.998614e-01
# male           6.100535e-01
# race           3.232725e-01
# ethnic         8.714513e-02
# prismrom       1.225127e-03
# ventfreeday    3.354073e-08
# PHENO          4.638273e-01
# dtype: float64
#
# stats models pckg: log model                             Logit Regression Results
# ...
# Dep. Variable:                death90   No. Observations:                  224
# Model:                          Logit   Df Residuals:                      217
# ...

# %%
CACNA2D3 = pd.read_csv("make_score/CACNA2D3.plink.profile",  sep=r"\s*")
CACNA2D3 = pd.merge(CACNA2D3, covariates, on="IID" )
axes = CACNA2D3.boxplot(column=['SCORE'], by='death90')

fig = axes.get_figure()
fig.suptitle('')

x = CACNA2D3[["SCORE", "male", "race", "ethnic", "prismrom", "ventfreeday", "PHENO"]]
y = CACNA2D3["death90"]
print(scipy.stats.ttest_ind(x,y))
print(" ")
print("-------------LOGISTIC REGRESSION BELOW-----------------")
print(" ")
log_model_sm = sm.Logit(y, x)
sm_result = log_model_sm.fit(maxiter=200)
print(" ")
print("Stats models logistic regression pvalues\n",sm_result.pvalues)

print(" ")
print("stats models pckg: log model ",sm_result.summary())
CACNA2D3.head()
# Out:
# Ttest_indResult(statistic=array([-6.16281488,  8.95841866, 34.54411864, 55.64835405, 12.16177579,
#        22.68567751, -4.63507663]), pvalue=array([1.59971979e-009, 9.02395961e-018, 3.79046362e-128, 8.03784693e-203,
#        1.37462701e-029, 2.52563270e-076, 4.69190550e-006]))
#
# -------------LOGISTIC REGRESSION BELOW-----------------
#
# Optimization terminated successfully.
#          Current function value: 0.213751
#          Iterations 9
#
# Stats models logistic regression pvalues
#  SCORE          9.492225e-01
# male           3.790392e-01
# race           2.717609e-01
# ethnic         2.424845e-02
# prismrom       6.647195e-04
# ventfreeday    6.194620e-08
# PHENO          2.057443e-01
# dtype: float64
#
# stats models pckg: log model                             Logit Regression Results
# ...
# Dep. Variable:                death90   No. Observations:                  224
# Model:                          Logit   Df Residuals:                      217
# ...

# %%
MDGA1 = pd.read_csv("make_score/MDGA1.plink.profile",  sep=r"\s*")
MDGA1 = pd.merge(MDGA1, covariates, on="IID" )
axes = MDGA1.boxplot(column=['SCORE'], by='death90')

fig = axes.get_figure()
fig.suptitle('')

x = MDGA1[["SCORE", "male", "race", "ethnic", "prismrom", "ventfreeday", "PHENO"]]
y = MDGA1["death90"]
print(scipy.stats.ttest_ind(x,y))
print(" ")
print("-------------LOGISTIC REGRESSION BELOW-----------------")
print(" ")
log_model_sm = sm.Logit(y, x)
sm_result = log_model_sm.fit(maxiter=200)
print(" ")
print("Stats models logistic regression pvalues\n",sm_result.pvalues)

print(" ")
print("stats models pckg: log model ",sm_result.summary())
MDGA1.head()
# Out:
# Ttest_indResult(statistic=array([-6.11669504,  8.95841866, 34.54411864, 55.64835405, 12.16177579,
#        22.68567751, -4.63507663]), pvalue=array([2.09069801e-009, 9.02395961e-018, 3.79046362e-128, 8.03784693e-203,
#        1.37462701e-029, 2.52563270e-076, 4.69190550e-006]))
#
# -------------LOGISTIC REGRESSION BELOW-----------------
#
# Optimization terminated successfully.
#          Current function value: 0.214137
#          Iterations 9
#
# Stats models logistic regression pvalues
#  SCORE          5.455828e-01
# male           4.926052e-01
# race           2.196081e-01
# ethnic         2.133084e-02
# prismrom       1.112419e-03
# ventfreeday    6.815097e-08
# PHENO          2.983870e-01
# dtype: float64
#
# stats models pckg: log model                             Logit Regression Results
# ...
# Dep. Variable:                death90   No. Observations:                  224
# Model:                          Logit   Df Residuals:                      217
# ...

# %%
PRTFDC1 = pd.read_csv("make_score/PRTFDC1.plink.profile", sep=r"\s*")
PRTFDC1 = pd.merge(PRTFDC1, covariates, on="IID" )
axes = PRTFDC1.boxplot(column=['SCORE'], by='death90')

fig = axes.get_figure()
fig.suptitle('')

x = PRTFDC1[["SCORE", "male", "race", "ethnic", "prismrom", "ventfreeday", "PHENO"]]
y = PRTFDC1["death90"]
print(scipy.stats.ttest_ind(x,y))
print(" ")
print("-------------LOGISTIC REGRESSION BELOW-----------------")
print(" ")

log_model_sm = sm.Logit(y, x)
sm_result = log_model_sm.fit(maxiter=200)
print(" ")
print("Stats models logistic regression pvalues\n",sm_result.pvalues)

print(" ")
print("stats models pckg: log model ",sm_result.summary())
PRTFDC1.head()
# Out:
# Ttest_indResult(statistic=array([-6.12782805,  8.95841866, 34.54411864, 55.64835405, 12.16177579,
#        22.68567751, -4.63507663]), pvalue=array([1.96017009e-009, 9.02395961e-018, 3.79046362e-128, 8.03784693e-203,
#        1.37462701e-029, 2.52563270e-076, 4.69190550e-006]))
#
# -------------LOGISTIC REGRESSION BELOW-----------------
#
# Optimization terminated successfully.
#          Current function value: 0.211253
#          Iterations 9
#
# Stats models logistic regression pvalues
#  SCORE          3.774124e-01
# male           4.436713e-01
# race           2.549315e-01
# ethnic         2.474898e-02
# prismrom       1.083034e-03
# ventfreeday    3.757253e-08
# PHENO          1.715843e-01
# dtype: float64
#
# stats models pckg: log model                             Logit Regression Results
# ...
# Dep. Variable:                death90   No. Observations:                  224
# Model:                          Logit   Df Residuals:                      217
# ...

# %%
TMPRSS9 = pd.read_csv("make_score/TMPRSS9.plink.profile",  sep=r"\s*")
TMPRSS9 = pd.merge(TMPRSS9, covariates, on="IID" )
axes = TMPRSS9.boxplot(column=['SCORE'], by='death90')

fig = axes.get_figure()
fig.suptitle('')

x = TMPRSS9[["SCORE", "male", "race", "ethnic", "prismrom", "ventfreeday", "PHENO"]]
y = TMPRSS9["death90"]

print(scipy.stats.ttest_ind(x,y))
print(" ")
print("-------------LOGISTIC REGRESSION BELOW-----------------")
print(" ")

log_model_sm = sm.Logit(y, x)
sm_result = log_model_sm.fit(maxiter=200)
print(" ")
print("Stats models logistic regression pvalues for ",sm_result.pvalues)

print(" ")
print("stats models pckg: log model ",sm_result.summary())
TMPRSS9.head()
# Out:
# Ttest_indResult(statistic=array([ 5.5450923 ,  8.95841866, 34.54411864, 55.64835405, 12.16177579,
#        22.68567751, -4.63507663]), pvalue=array([5.04001717e-008, 9.02395961e-018, 3.79046362e-128, 8.03784693e-203,
#        1.37462701e-029, 2.52563270e-076, 4.69190550e-006]))
#
# -------------LOGISTIC REGRESSION BELOW-----------------
#
# Optimization terminated successfully.
#          Current function value: 0.214082
#          Iterations 8
#
# Stats models logistic regression pvalues for  SCORE          6.307355e-01
# male           4.547444e-01
# race           2.686192e-01
# ethnic         2.298803e-02
# prismrom       7.769993e-04
# ventfreeday    1.010882e-07
# PHENO          2.178366e-01
# dtype: float64
#
# stats models pckg: log model                             Logit Regression Results
# ...
# Dep. Variable:                death90   No. Observations:                  224
# Model:                          Logit   Df Residuals:                      217
# ...

# %%
WLS = pd.read_csv("make_score/WLS.plink.profile",  sep=r"\s*")
WLS = pd.merge(WLS, covariates, on="IID" )
axes = WLS.boxplot(column=['SCORE'], by='death90')

fig = axes.get_figure()
fig.suptitle('')

x = WLS[["SCORE", "male", "race", "ethnic", "prismrom", "ventfreeday", "PHENO"]]
y = WLS["death90"]

print(scipy.stats.ttest_ind(x,y))
print(" ")
print("-------------LOGISTIC REGRESSION BELOW-----------------")
print(" ")
log_model_sm = sm.Logit(y, x)
sm_result = log_model_sm.fit(maxiter=200)
print(" ")
print("Stats models logistic regression pvalues\n",sm_result.pvalues)

print(" ")
print("stats models pckg: log model ",sm_result.summary())
WLS.head()
# Out:
# Ttest_indResult(statistic=array([-11.1159718 ,   8.95841866,  34.54411864,  55.64835405,
#         12.16177579,  22.68567751,  -4.63507663]), pvalue=array([1.66329708e-025, 9.02395961e-018, 3.79046362e-128, 8.03784693e-203,
#        1.37462701e-029, 2.52563270e-076, 4.69190550e-006]))
#
# -------------LOGISTIC REGRESSION BELOW-----------------
#
# Optimization terminated successfully.
#          Current function value: 0.209403
#          Iterations 8
#
# Stats models logistic regression pvalues
#  SCORE          1.958344e-01
# male           4.293165e-01
# race           2.000876e-01
# ethnic         1.573284e-02
# prismrom       1.124963e-03
# ventfreeday    4.776065e-08
# PHENO          2.529527e-01
# dtype: float64
#
# stats models pckg: log model                             Logit Regression Results
# ...
# Dep. Variable:                death90   No. Observations:                  224
# Model:                          Logit   Df Residuals:                      217
# ...

# %%
# log_model_scikit = LogisticRegression(C=1000)
# log_model_scikit.fit(x, y)
# print("scikit learn pckg: log model coefficient ", log_model_scikit.coef_) #show coefficients
